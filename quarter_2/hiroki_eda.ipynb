# %%
import os
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading Data using Pandas and SQLite3

# %%
# helper function to join tables across different database (.db) files
def join_tables(tables):
    
    df = tables[0]
    for table in tables[1:]:
        df = pd.concat([df, table])
        
    return df.reset_index(drop=True)

# joining all database (.db) files of folder
def get_all_databases(folder):
    
    string_tables = []
    ull_tables = []
    files = os.listdir(folder)
    
    # iterating through all files of folder to append tables
    for file in files:
        path = os.path.join(folder, file)
        con = sqlite3.connect(path)
        string_tables.append(pd.read_sql_query('SELECT * FROM COUNTERS_STRING_TIME_DATA', con))
        ull_tables.append(pd.read_sql_query('SELECT * FROM COUNTERS_ULL_TIME_DATA', con))
        
    # concatenating tables into single DataFrames
    string_df = join_tables(string_tables)
    string_df.loc[:, 'VALUE'] = string_df.loc[:, 'VALUE'].replace({'WWAHost.exe': 'Netflix.exe'}) 
    ull_df = join_tables(ull_tables)
    
    return (string_df, ull_df)

# %%
# LAPTOP-MP2GILK8
string_df_0, ull_df_0 = get_all_databases('group3_collected_data')

# DESKTOP-E83M0TM
string_df_1, ull_df_1 = get_all_databases('group3_collected_data_pc_1')

# %%
display(string_df_0.head())
display(ull_df_0.head())
# Out:
#           MEASUREMENT_TIME  ID_INPUT       VALUE PRIVATE_DATA
# 0  2021-11-20 21:30:29.491         2   IDC_ARROW            0
# 1  2021-11-20 21:30:30.578         3     cmd.exe            0
# 2  2021-11-20 21:30:31.512         2  IDC_SIZEWE            0
# 3  2021-11-20 21:30:31.847         2   IDC_ARROW            0
# 4  2021-11-20 21:30:34.994         2    IDC_HAND            0
#           MEASUREMENT_TIME ID_INPUT VALUE PRIVATE_DATA
# 0  2021-11-20 21:30:29.436        0   791            0
# 1  2021-11-20 21:30:29.436        1   108            0
# 2  2021-11-20 21:30:30.442        0   814            0
# 3  2021-11-20 21:30:30.442        1    70            0
# 4  2021-11-20 21:30:30.578        4  2072            0

# %% [markdown]
# # Exploratory Data Analysis

# %%
# getting value counts of foreground applications on LAPTOP-MP2GILK8
foreground_apps = string_df_0[string_df_0['ID_INPUT'] == 3]['VALUE']
foreground_apps = foreground_apps.tolist()

# %%
pairs = []
for i in range(len(foreground_apps)-1):
    pairs.append((foreground_apps[i], foreground_apps[i+1]))
pairs
# Out:
# [('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'msedge.exe'),
#  ('msedge.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'msedge.exe'),
#  ('msedge.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'msedge.exe'),
#  ('msedge.exe', 'chrome.exe'),
#  ('chrome.exe', 'msedge.exe'),
#  ('msedge.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'msedge.exe'),
#  ('msedge.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'chrome.exe'),
#  ('chrome.exe', 'Installer.exe'),
#  ('Installer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'LenovoVantage.exe'),
#  ('LenovoVantage.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Teams.exe'),
#  ('Teams.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'explorer.exe'),
#  ('explorer.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'StartMenuExperienceHost.exe'),
#  ('StartMenuExperienceHost.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Teams.exe'),
#  ('Teams.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'Teams.exe'),
#  ('Teams.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'python.exe'),
#  ('python.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'explorer.exe'),
#  ('explorer.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'explorer.exe'),
#  ('explorer.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Zoom.exe'),
#  ('Zoom.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Taskmgr.exe'),
#  ('Taskmgr.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'cmd.exe'),
#  ('cmd.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Teams.exe'),
#  ('Teams.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'GUP.exe'),
#  ('GUP.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'npp.8.1.9.2.Installer.exe'),
#  ('npp.8.1.9.2.Installer.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'mmc.exe'),
#  ('mmc.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'cmd.exe'),
#  ('cmd.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'explorer.exe'),
#  ('explorer.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'mmc.exe'),
#  ('mmc.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'mmc.exe'),
#  ('mmc.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'mmc.exe'),
#  ('mmc.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Taskmgr.exe'),
#  ('Taskmgr.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'mmc.exe'),
#  ('mmc.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad++.exe'),
#  ('notepad++.exe', 'explorer.exe'),
#  ('explorer.exe', 'mmc.exe'),
#  ('mmc.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'chrome.exe'),
#  ('chrome.exe', 'HxOutlook.exe'),
#  ('HxOutlook.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'notepad.exe'),
#  ('notepad.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'HxOutlook.exe'),
#  ('HxOutlook.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'Taskmgr.exe'),
#  ('Taskmgr.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'SndVol.exe'),
#  ('SndVol.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'Discord.exe'),
#  ('Discord.exe', 'Microsoft.AAD.BrokerPlugin.exe'),
#  ('Microsoft.AAD.BrokerPlugin.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Teams.exe'),
#  ('Teams.exe', 'Microsoft.Notes.exe'),
#  ('Microsoft.Notes.exe', 'notepad.exe'),
#  ('notepad.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'chrome.exe'),
#  ('chrome.exe', 'notepad.exe'),
#  ('notepad.exe', 'explorer.exe'),
#  ('explorer.exe', 'Microsoft.Notes.exe'),
#  ('Microsoft.Notes.exe', 'chrome.exe'),
#  ('chrome.exe', 'Microsoft.Notes.exe'),
#  ('Microsoft.Notes.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Teams.exe'),
#  ('Teams.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'ScreenClippingHost.exe'),
#  ('ScreenClippingHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'cmd.exe'),
#  ('cmd.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'notepad.exe'),
#  ('notepad.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'WerFault.exe'),
#  ('WerFault.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'SndVol.exe'),
#  ('SndVol.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'explorer.exe'),
#  ('explorer.exe', 'Discord.exe'),
#  ('Discord.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'chrome.exe'),
#  ('chrome.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'explorer.exe'),
#  ('explorer.exe', 'Taskmgr.exe'),
#  ('Taskmgr.exe', 'GitHubDesktop.exe'),
#  ('GitHubDesktop.exe', 'Taskmgr.exe'),
#  ('Taskmgr.exe', 'explorer.exe'),
#  ('explorer.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'explorer.exe'),
#  ('explorer.exe', 'SearchApp.exe'),
#  ('SearchApp.exe', 'StartMenuExperienceHost.exe'),
#  ('StartMenuExperienceHost.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'chrome.exe'),
#  ('chrome.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'msedge.exe'),
#  ('msedge.exe', 'chrome.exe'),
#  ('chrome.exe', 'msedge.exe'),
#  ('msedge.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'msedge.exe'),
#  ('msedge.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'ScreenClippingHost.exe'),
#  ('ScreenClippingHost.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'Discord.exe'),
#  ('Discord.exe', 'chrome.exe'),
#  ('chrome.exe', 'cmd.exe'),
#  ('cmd.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'Discord.exe'),
#  ('Discord.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'chrome.exe'),
#  ('chrome.exe', 'explorer.exe'),
#  ('explorer.exe', 'cmd.exe'),
#  ('cmd.exe', 'devenv.exe'),
#  ('devenv.exe', 'cmd.exe'),
#  ('cmd.exe', 'devenv.exe'),
#  ('devenv.exe', 'ShellExperienceHost.exe'),
#  ('ShellExperienceHost.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'chrome.exe'),
#  ('chrome.exe', 'SystemSettings.exe'),
#  ('SystemSettings.exe', 'devenv.exe'),
#  ('devenv.exe', 'cmd.exe'),
#  ('cmd.exe', 'devenv.exe'),
#  ('devenv.exe', 'chrome.exe'),
#  ('chrome.exe', 'devenv.exe'),
#  ('devenv.exe', 'explorer.exe'),
#  ('explorer.exe', 'devenv.exe'),
#  ('devenv.exe', 'VsDebugConsole.exe'),
#  ('VsDebugConsole.exe', 'devenv.exe'),
#  ('devenv.exe', 'VsDebugConsole.exe'),
#  ('VsDebugConsole.exe', 'chrome.exe'),
#  ('chrome.exe', 'VsDebugConsole.exe'),
#  ('VsDebugConsole.exe', 'explorer.exe'),
#  ('explorer.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'chrome.exe'),
#  ('chrome.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'explorer.exe'),
#  ('explorer.exe', 'Spotify.exe'),
#  ('Spotify.exe', 'Discord.exe'),
#  ('Discord.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'devenv.exe'),
#  ('devenv.exe', 'DB Browser for SQLite.exe'),
#  ('DB Browser for SQLite.exe', 'devenv.exe'),
#  ('devenv.exe', 'Spotify.exe'),
#  ...]

# %%
applist = pd.Series(foreground_apps).unique()
applist = applist.tolist()

# %%
l = {}
for i in applist:
    k = {}
    for j in pairs:
        if j[0] == i:
            if j[1] not in k:
                k[j[1]] = 1
            else:
                k[j[1]] += 1
    l[i] = k
l
# Out:
# {'cmd.exe': {'explorer.exe': 55,
#   'msedge.exe': 3,
#   'chrome.exe': 117,
#   'Discord.exe': 15,
#   'ShellExperienceHost.exe': 4,
#   'SearchApp.exe': 3,
#   'python.exe': 6,
#   'Teams.exe': 2,
#   'Spotify.exe': 9,
#   'cmd.exe': 8,
#   'notepad++.exe': 2,
#   'devenv.exe': 7,
#   'Microsoft.AAD.BrokerPlugin.exe': 1,
#   'DB Browser for SQLite.exe': 2,
#   'SystemSettings.exe': 1,
#   'ScreenClippingHost.exe': 2,
#   'vpnui.exe': 1,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 1},
#  'explorer.exe': {'chrome.exe': 248,
#   'cmd.exe': 111,
#   'Discord.exe': 33,
#   'Teams.exe': 57,
#   'Zoom.exe': 15,
#   'SystemSettings.exe': 20,
#   'DB Browser for SQLite.exe': 84,
#   'notepad++.exe': 4,
#   'SearchApp.exe': 6,
#   'Taskmgr.exe': 4,
#   'mmc.exe': 2,
#   'Spotify.exe': 18,
#   'SndVol.exe': 16,
#   'Microsoft.Notes.exe': 1,
#   'GitHubDesktop.exe': 3,
#   'notepad.exe': 3,
#   'msedge.exe': 6,
#   'devenv.exe': 59,
#   'OpenWith.exe': 1,
#   'VsDebugConsole.exe': 1,
#   'HxOutlook.exe': 1,
#   'ShellExperienceHost.exe': 4,
#   'Microsoft.AAD.BrokerPlugin.exe': 2,
#   'ScreenClippingHost.exe': 2,
#   'WindowsCamera.exe': 2,
#   'Video.UI.exe': 1,
#   'rundll32.exe': 2,
#   'Netflix.exe': 8,
#   'PaintStudio.View.exe': 4,
#   'explorer.exe': 1,
#   'LockApp.exe': 2,
#   'Microsoft.Photos.exe': 3,
#   'steam.exe': 2,
#   'vpnui.exe': 3,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 1},
#  'chrome.exe': {'explorer.exe': 266,
#   'msedge.exe': 7,
#   'Spotify.exe': 71,
#   'cmd.exe': 82,
#   'Discord.exe': 183,
#   'Microsoft.AAD.BrokerPlugin.exe': 7,
#   'Teams.exe': 66,
#   'Zoom.exe': 68,
#   'Installer.exe': 1,
#   'LenovoVantage.exe': 1,
#   'ShellExperienceHost.exe': 37,
#   'Taskmgr.exe': 3,
#   'chrome.exe': 3,
#   'SearchApp.exe': 26,
#   'notepad++.exe': 5,
#   'mmc.exe': 2,
#   'DB Browser for SQLite.exe': 30,
#   'notepad.exe': 10,
#   'HxOutlook.exe': 2,
#   'Microsoft.Notes.exe': 1,
#   'GitHubDesktop.exe': 3,
#   'SystemSettings.exe': 5,
#   'devenv.exe': 77,
#   'VsDebugConsole.exe': 1,
#   'SndVol.exe': 5,
#   'LockApp.exe': 1,
#   'WindowsCamera.exe': 5,
#   'Video.UI.exe': 2,
#   'EaseOfAccessDialog.exe': 1,
#   'ScreenClippingHost.exe': 9,
#   'ApplicationFrameHost.exe': 1,
#   'WinStore.App.exe': 1,
#   'rundll32.exe': 1,
#   'Netflix.exe': 26,
#   'StartMenuExperienceHost.exe': 2,
#   'python.exe': 3,
#   'Microsoft.Photos.exe': 2,
#   'zCefAgent.exe': 1,
#   'steam.exe': 4,
#   'steamwebhelper.exe': 3,
#   'msiexec.exe': 1,
#   'vpnui.exe': 1,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 2},
#  'msedge.exe': {'chrome.exe': 8,
#   'explorer.exe': 9,
#   'devenv.exe': 7,
#   'Teams.exe': 2,
#   'Spotify.exe': 1,
#   'DB Browser for SQLite.exe': 1,
#   'LockApp.exe': 1,
#   'vpnui.exe': 1},
#  'Spotify.exe': {'ShellExperienceHost.exe': 10,
#   'SystemSettings.exe': 3,
#   'chrome.exe': 67,
#   'explorer.exe': 31,
#   'msedge.exe': 2,
#   'Discord.exe': 18,
#   'cmd.exe': 4,
#   'notepad.exe': 1,
#   'Taskmgr.exe': 1,
#   'devenv.exe': 7,
#   'Teams.exe': 4,
#   'DB Browser for SQLite.exe': 3,
#   'Zoom.exe': 1,
#   'Netflix.exe': 5},
#  'ShellExperienceHost.exe': {'SystemSettings.exe': 27,
#   'explorer.exe': 8,
#   'Zoom.exe': 1,
#   'Discord.exe': 2,
#   'chrome.exe': 21,
#   'WerFault.exe': 1,
#   'Spotify.exe': 6,
#   'devenv.exe': 2,
#   'cmd.exe': 2,
#   'Netflix.exe': 3,
#   'steam.exe': 1},
#  'SystemSettings.exe': {'Spotify.exe': 7,
#   'chrome.exe': 21,
#   'explorer.exe': 12,
#   'Zoom.exe': 5,
#   'Discord.exe': 3,
#   'cmd.exe': 1,
#   'devenv.exe': 1,
#   'Teams.exe': 3,
#   'rundll32.exe': 1,
#   'ShellExperienceHost.exe': 2,
#   'Netflix.exe': 5,
#   'LockApp.exe': 1,
#   'SndVol.exe': 3},
#  'Discord.exe': {'explorer.exe': 48,
#   'Spotify.exe': 21,
#   'chrome.exe': 186,
#   'ShellExperienceHost.exe': 3,
#   'cmd.exe': 8,
#   'HxOutlook.exe': 1,
#   'Microsoft.AAD.BrokerPlugin.exe': 3,
#   'ScreenClippingHost.exe': 2,
#   'DB Browser for SQLite.exe': 5,
#   'Zoom.exe': 27,
#   'Teams.exe': 17,
#   'devenv.exe': 10,
#   'Taskmgr.exe': 1,
#   'mmc.exe': 1,
#   'python.exe': 2,
#   'Netflix.exe': 1,
#   'SearchApp.exe': 1,
#   'SndVol.exe': 3,
#   'steamwebhelper.exe': 2},
#  'Microsoft.AAD.BrokerPlugin.exe': {'Teams.exe': 11,
#   'chrome.exe': 4,
#   'explorer.exe': 3,
#   'Discord.exe': 3,
#   'cmd.exe': 1,
#   'mmc.exe': 1},
#  'Teams.exe': {'chrome.exe': 71,
#   'explorer.exe': 56,
#   'Spotify.exe': 5,
#   'Microsoft.Notes.exe': 1,
#   'devenv.exe': 67,
#   'msedge.exe': 3,
#   'Discord.exe': 18,
#   'DB Browser for SQLite.exe': 6,
#   'Microsoft.AAD.BrokerPlugin.exe': 8,
#   'ShellExperienceHost.exe': 1,
#   'steamwebhelper.exe': 1,
#   'Taskmgr.exe': 2},
#  'Zoom.exe': {'chrome.exe': 70,
#   'Teams.exe': 1,
#   'explorer.exe': 8,
#   'ShellExperienceHost.exe': 2,
#   'Discord.exe': 32,
#   'DB Browser for SQLite.exe': 1,
#   'SystemSettings.exe': 3,
#   'Spotify.exe': 1,
#   'SndVol.exe': 1},
#  'Installer.exe': {'chrome.exe': 1},
#  'LenovoVantage.exe': {'chrome.exe': 1},
#  'SearchApp.exe': {'explorer.exe': 6,
#   'StartMenuExperienceHost.exe': 6,
#   'chrome.exe': 16,
#   'DB Browser for SQLite.exe': 4,
#   'cmd.exe': 2,
#   'notepad++.exe': 2,
#   'npp.8.1.9.2.Installer.exe': 1,
#   'Discord.exe': 2,
#   'mmc.exe': 1,
#   'ShellExperienceHost.exe': 1,
#   'WinStore.App.exe': 1,
#   'Netflix.exe': 2,
#   'SystemSettings.exe': 1},
#  'StartMenuExperienceHost.exe': {'cmd.exe': 2,
#   'Netflix.exe': 2,
#   'chrome.exe': 2,
#   'SearchApp.exe': 4,
#   'SystemSettings.exe': 1},
#  'DB Browser for SQLite.exe': {'explorer.exe': 61,
#   'SearchApp.exe': 2,
#   'chrome.exe': 24,
#   'Spotify.exe': 4,
#   'devenv.exe': 45,
#   'msedge.exe': 4,
#   'Discord.exe': 5,
#   'cmd.exe': 2,
#   'Teams.exe': 11,
#   'Taskmgr.exe': 1,
#   'ScreenClippingHost.exe': 4,
#   'Netflix.exe': 1},
#  'python.exe': {'explorer.exe': 2,
#   'cmd.exe': 3,
#   'Netflix.exe': 5,
#   'Discord.exe': 3,
#   'ScreenSketch.exe': 1,
#   'ScreenClippingHost.exe': 2,
#   'chrome.exe': 1},
#  'Taskmgr.exe': {'chrome.exe': 3,
#   'Microsoft.AAD.BrokerPlugin.exe': 1,
#   'GitHubDesktop.exe': 1,
#   'explorer.exe': 2,
#   'devenv.exe': 2,
#   'cmd.exe': 1,
#   'Spotify.exe': 1,
#   'Teams.exe': 1,
#   'DB Browser for SQLite.exe': 1,
#   'msedge.exe': 1,
#   'vpnui.exe': 1},
#  'notepad++.exe': {'explorer.exe': 6,
#   'GUP.exe': 1,
#   'mmc.exe': 3,
#   'cmd.exe': 1,
#   'chrome.exe': 3},
#  'GUP.exe': {'SearchApp.exe': 1},
#  'npp.8.1.9.2.Installer.exe': {'SearchApp.exe': 1},
#  'mmc.exe': {'explorer.exe': 3,
#   'notepad++.exe': 1,
#   'chrome.exe': 3,
#   'DB Browser for SQLite.exe': 1,
#   'Discord.exe': 1,
#   'SearchApp.exe': 1},
#  'notepad.exe': {'explorer.exe': 2,
#   'chrome.exe': 8,
#   'Spotify.exe': 1,
#   'Discord.exe': 1,
#   'Teams.exe': 1,
#   'GitHubDesktop.exe': 1,
#   'devenv.exe': 1},
#  'HxOutlook.exe': {'chrome.exe': 2, 'explorer.exe': 2},
#  'SndVol.exe': {'Spotify.exe': 1,
#   'Discord.exe': 5,
#   'chrome.exe': 12,
#   'explorer.exe': 8,
#   'ShellExperienceHost.exe': 1,
#   'Zoom.exe': 1,
#   'SystemSettings.exe': 1,
#   'StartMenuExperienceHost.exe': 1,
#   'Teams.exe': 1,
#   'steamwebhelper.exe': 1},
#  'Microsoft.Notes.exe': {'notepad.exe': 1, 'chrome.exe': 2},
#  'ScreenClippingHost.exe': {'chrome.exe': 7,
#   'Discord.exe': 1,
#   'Teams.exe': 1,
#   'DB Browser for SQLite.exe': 2,
#   'explorer.exe': 2,
#   'PickerHost.exe': 2,
#   'cmd.exe': 1,
#   'ScreenSketch.exe': 3,
#   'python.exe': 1,
#   'Zoom.exe': 1},
#  'GitHubDesktop.exe': {'explorer.exe': 5,
#   'ShellExperienceHost.exe': 1,
#   'chrome.exe': 1,
#   'Taskmgr.exe': 1},
#  'WerFault.exe': {'explorer.exe': 1},
#  'devenv.exe': {'cmd.exe': 4,
#   'ShellExperienceHost.exe': 2,
#   'chrome.exe': 75,
#   'explorer.exe': 86,
#   'VsDebugConsole.exe': 48,
#   'DB Browser for SQLite.exe': 23,
#   'Spotify.exe': 5,
#   'Teams.exe': 57,
#   'msedge.exe': 4,
#   'Discord.exe': 13,
#   'Taskmgr.exe': 1,
#   'Microsoft.AAD.BrokerPlugin.exe': 1,
#   'SndVol.exe': 1},
#  'VsDebugConsole.exe': {'devenv.exe': 35,
#   'chrome.exe': 3,
#   'explorer.exe': 10,
#   'DB Browser for SQLite.exe': 1,
#   'Teams.exe': 1},
#  'OpenWith.exe': {'explorer.exe': 1},
#  'LockApp.exe': {'Teams.exe': 1,
#   'explorer.exe': 2,
#   'SystemSettings.exe': 1,
#   'ApplicationFrameHost.exe': 1},
#  'WindowsCamera.exe': {'chrome.exe': 4, 'explorer.exe': 3},
#  'Video.UI.exe': {'explorer.exe': 2, 'chrome.exe': 1},
#  'EaseOfAccessDialog.exe': {'chrome.exe': 1},
#  'ApplicationFrameHost.exe': {'Discord.exe': 1, 'chrome.exe': 1},
#  'WinStore.App.exe': {'chrome.exe': 2,
#   'cmd.exe': 1,
#   'Netflix.exe': 1,
#   'rundll32.exe': 1},
#  'rundll32.exe': {'explorer.exe': 3, 'WinStore.App.exe': 2},
#  'Netflix.exe': {'WinStore.App.exe': 1,
#   'explorer.exe': 14,
#   'chrome.exe': 24,
#   'ShellExperienceHost.exe': 5,
#   'NVIDIA Notification.exe': 1,
#   'SystemSettings.exe': 2,
#   'Spotify.exe': 6,
#   'StartMenuExperienceHost.exe': 2,
#   'python.exe': 3,
#   'Discord.exe': 2,
#   'Teams.exe': 1},
#  'NVIDIA Notification.exe': {'Netflix.exe': 1},
#  'PaintStudio.View.exe': {'explorer.exe': 4},
#  'PickerHost.exe': {'chrome.exe': 1, 'ScreenSketch.exe': 1},
#  'ScreenSketch.exe': {'cmd.exe': 2, 'explorer.exe': 1, 'python.exe': 2},
#  'Microsoft.Photos.exe': {'explorer.exe': 2, 'chrome.exe': 3},
#  'zCefAgent.exe': {'chrome.exe': 1},
#  'steam.exe': {'explorer.exe': 1,
#   'SndVol.exe': 1,
#   'chrome.exe': 3,
#   'Discord.exe': 1,
#   'steamwebhelper.exe': 5},
#  'steamwebhelper.exe': {'steam.exe': 4,
#   'ShellExperienceHost.exe': 1,
#   'chrome.exe': 3,
#   'explorer.exe': 1,
#   'SndVol.exe': 2,
#   'Teams.exe': 1},
#  'msiexec.exe': {'chrome.exe': 1},
#  'vpnui.exe': {'cmd.exe': 1,
#   'explorer.exe': 3,
#   'Taskmgr.exe': 1,
#   'chrome.exe': 1,
#   'Netflix.exe': 1},
#  'Anaconda3-2021.11-Windows-x86_64.exe': {'chrome.exe': 2, 'cmd.exe': 2}}

# %%
sum(l['cmd.exe'].values())
# Out:
# 239

# %%
for i in l.keys():
    s = sum(l[i].values())
    for j in l[i].keys():
        l[i][j] = l[i][j] / s
l
# Out:
# {'cmd.exe': {'explorer.exe': 0.2301255230125523,
#   'msedge.exe': 0.012552301255230125,
#   'chrome.exe': 0.4895397489539749,
#   'Discord.exe': 0.06276150627615062,
#   'ShellExperienceHost.exe': 0.016736401673640166,
#   'SearchApp.exe': 0.012552301255230125,
#   'python.exe': 0.02510460251046025,
#   'Teams.exe': 0.008368200836820083,
#   'Spotify.exe': 0.03765690376569038,
#   'cmd.exe': 0.03347280334728033,
#   'notepad++.exe': 0.008368200836820083,
#   'devenv.exe': 0.029288702928870293,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.0041841004184100415,
#   'DB Browser for SQLite.exe': 0.008368200836820083,
#   'SystemSettings.exe': 0.0041841004184100415,
#   'ScreenClippingHost.exe': 0.008368200836820083,
#   'vpnui.exe': 0.0041841004184100415,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 0.0041841004184100415},
#  'explorer.exe': {'chrome.exe': 0.33972602739726027,
#   'cmd.exe': 0.15205479452054796,
#   'Discord.exe': 0.045205479452054796,
#   'Teams.exe': 0.07808219178082192,
#   'Zoom.exe': 0.02054794520547945,
#   'SystemSettings.exe': 0.0273972602739726,
#   'DB Browser for SQLite.exe': 0.11506849315068493,
#   'notepad++.exe': 0.005479452054794521,
#   'SearchApp.exe': 0.00821917808219178,
#   'Taskmgr.exe': 0.005479452054794521,
#   'mmc.exe': 0.0027397260273972603,
#   'Spotify.exe': 0.024657534246575342,
#   'SndVol.exe': 0.021917808219178082,
#   'Microsoft.Notes.exe': 0.0013698630136986301,
#   'GitHubDesktop.exe': 0.00410958904109589,
#   'notepad.exe': 0.00410958904109589,
#   'msedge.exe': 0.00821917808219178,
#   'devenv.exe': 0.08082191780821918,
#   'OpenWith.exe': 0.0013698630136986301,
#   'VsDebugConsole.exe': 0.0013698630136986301,
#   'HxOutlook.exe': 0.0013698630136986301,
#   'ShellExperienceHost.exe': 0.005479452054794521,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.0027397260273972603,
#   'ScreenClippingHost.exe': 0.0027397260273972603,
#   'WindowsCamera.exe': 0.0027397260273972603,
#   'Video.UI.exe': 0.0013698630136986301,
#   'rundll32.exe': 0.0027397260273972603,
#   'Netflix.exe': 0.010958904109589041,
#   'PaintStudio.View.exe': 0.005479452054794521,
#   'explorer.exe': 0.0013698630136986301,
#   'LockApp.exe': 0.0027397260273972603,
#   'Microsoft.Photos.exe': 0.00410958904109589,
#   'steam.exe': 0.0027397260273972603,
#   'vpnui.exe': 0.00410958904109589,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 0.0013698630136986301},
#  'chrome.exe': {'explorer.exe': 0.2587548638132296,
#   'msedge.exe': 0.006809338521400778,
#   'Spotify.exe': 0.06906614785992218,
#   'cmd.exe': 0.07976653696498054,
#   'Discord.exe': 0.17801556420233464,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.006809338521400778,
#   'Teams.exe': 0.06420233463035019,
#   'Zoom.exe': 0.06614785992217899,
#   'Installer.exe': 0.0009727626459143969,
#   'LenovoVantage.exe': 0.0009727626459143969,
#   'ShellExperienceHost.exe': 0.03599221789883268,
#   'Taskmgr.exe': 0.0029182879377431907,
#   'chrome.exe': 0.0029182879377431907,
#   'SearchApp.exe': 0.02529182879377432,
#   'notepad++.exe': 0.0048638132295719845,
#   'mmc.exe': 0.0019455252918287938,
#   'DB Browser for SQLite.exe': 0.029182879377431907,
#   'notepad.exe': 0.009727626459143969,
#   'HxOutlook.exe': 0.0019455252918287938,
#   'Microsoft.Notes.exe': 0.0009727626459143969,
#   'GitHubDesktop.exe': 0.0029182879377431907,
#   'SystemSettings.exe': 0.0048638132295719845,
#   'devenv.exe': 0.07490272373540856,
#   'VsDebugConsole.exe': 0.0009727626459143969,
#   'SndVol.exe': 0.0048638132295719845,
#   'LockApp.exe': 0.0009727626459143969,
#   'WindowsCamera.exe': 0.0048638132295719845,
#   'Video.UI.exe': 0.0019455252918287938,
#   'EaseOfAccessDialog.exe': 0.0009727626459143969,
#   'ScreenClippingHost.exe': 0.008754863813229572,
#   'ApplicationFrameHost.exe': 0.0009727626459143969,
#   'WinStore.App.exe': 0.0009727626459143969,
#   'rundll32.exe': 0.0009727626459143969,
#   'Netflix.exe': 0.02529182879377432,
#   'StartMenuExperienceHost.exe': 0.0019455252918287938,
#   'python.exe': 0.0029182879377431907,
#   'Microsoft.Photos.exe': 0.0019455252918287938,
#   'zCefAgent.exe': 0.0009727626459143969,
#   'steam.exe': 0.0038910505836575876,
#   'steamwebhelper.exe': 0.0029182879377431907,
#   'msiexec.exe': 0.0009727626459143969,
#   'vpnui.exe': 0.0009727626459143969,
#   'Anaconda3-2021.11-Windows-x86_64.exe': 0.0019455252918287938},
#  'msedge.exe': {'chrome.exe': 0.26666666666666666,
#   'explorer.exe': 0.3,
#   'devenv.exe': 0.23333333333333334,
#   'Teams.exe': 0.06666666666666667,
#   'Spotify.exe': 0.03333333333333333,
#   'DB Browser for SQLite.exe': 0.03333333333333333,
#   'LockApp.exe': 0.03333333333333333,
#   'vpnui.exe': 0.03333333333333333},
#  'Spotify.exe': {'ShellExperienceHost.exe': 0.06369426751592357,
#   'SystemSettings.exe': 0.01910828025477707,
#   'chrome.exe': 0.4267515923566879,
#   'explorer.exe': 0.19745222929936307,
#   'msedge.exe': 0.012738853503184714,
#   'Discord.exe': 0.11464968152866242,
#   'cmd.exe': 0.025477707006369428,
#   'notepad.exe': 0.006369426751592357,
#   'Taskmgr.exe': 0.006369426751592357,
#   'devenv.exe': 0.044585987261146494,
#   'Teams.exe': 0.025477707006369428,
#   'DB Browser for SQLite.exe': 0.01910828025477707,
#   'Zoom.exe': 0.006369426751592357,
#   'Netflix.exe': 0.03184713375796178},
#  'ShellExperienceHost.exe': {'SystemSettings.exe': 0.36486486486486486,
#   'explorer.exe': 0.10810810810810811,
#   'Zoom.exe': 0.013513513513513514,
#   'Discord.exe': 0.02702702702702703,
#   'chrome.exe': 0.28378378378378377,
#   'WerFault.exe': 0.013513513513513514,
#   'Spotify.exe': 0.08108108108108109,
#   'devenv.exe': 0.02702702702702703,
#   'cmd.exe': 0.02702702702702703,
#   'Netflix.exe': 0.04054054054054054,
#   'steam.exe': 0.013513513513513514},
#  'SystemSettings.exe': {'Spotify.exe': 0.1076923076923077,
#   'chrome.exe': 0.3230769230769231,
#   'explorer.exe': 0.18461538461538463,
#   'Zoom.exe': 0.07692307692307693,
#   'Discord.exe': 0.046153846153846156,
#   'cmd.exe': 0.015384615384615385,
#   'devenv.exe': 0.015384615384615385,
#   'Teams.exe': 0.046153846153846156,
#   'rundll32.exe': 0.015384615384615385,
#   'ShellExperienceHost.exe': 0.03076923076923077,
#   'Netflix.exe': 0.07692307692307693,
#   'LockApp.exe': 0.015384615384615385,
#   'SndVol.exe': 0.046153846153846156},
#  'Discord.exe': {'explorer.exe': 0.14035087719298245,
#   'Spotify.exe': 0.06140350877192982,
#   'chrome.exe': 0.543859649122807,
#   'ShellExperienceHost.exe': 0.008771929824561403,
#   'cmd.exe': 0.023391812865497075,
#   'HxOutlook.exe': 0.0029239766081871343,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.008771929824561403,
#   'ScreenClippingHost.exe': 0.005847953216374269,
#   'DB Browser for SQLite.exe': 0.014619883040935672,
#   'Zoom.exe': 0.07894736842105263,
#   'Teams.exe': 0.049707602339181284,
#   'devenv.exe': 0.029239766081871343,
#   'Taskmgr.exe': 0.0029239766081871343,
#   'mmc.exe': 0.0029239766081871343,
#   'python.exe': 0.005847953216374269,
#   'Netflix.exe': 0.0029239766081871343,
#   'SearchApp.exe': 0.0029239766081871343,
#   'SndVol.exe': 0.008771929824561403,
#   'steamwebhelper.exe': 0.005847953216374269},
#  'Microsoft.AAD.BrokerPlugin.exe': {'Teams.exe': 0.4782608695652174,
#   'chrome.exe': 0.17391304347826086,
#   'explorer.exe': 0.13043478260869565,
#   'Discord.exe': 0.13043478260869565,
#   'cmd.exe': 0.043478260869565216,
#   'mmc.exe': 0.043478260869565216},
#  'Teams.exe': {'chrome.exe': 0.29707112970711297,
#   'explorer.exe': 0.23430962343096234,
#   'Spotify.exe': 0.02092050209205021,
#   'Microsoft.Notes.exe': 0.0041841004184100415,
#   'devenv.exe': 0.2803347280334728,
#   'msedge.exe': 0.012552301255230125,
#   'Discord.exe': 0.07531380753138076,
#   'DB Browser for SQLite.exe': 0.02510460251046025,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.03347280334728033,
#   'ShellExperienceHost.exe': 0.0041841004184100415,
#   'steamwebhelper.exe': 0.0041841004184100415,
#   'Taskmgr.exe': 0.008368200836820083},
#  'Zoom.exe': {'chrome.exe': 0.5882352941176471,
#   'Teams.exe': 0.008403361344537815,
#   'explorer.exe': 0.06722689075630252,
#   'ShellExperienceHost.exe': 0.01680672268907563,
#   'Discord.exe': 0.2689075630252101,
#   'DB Browser for SQLite.exe': 0.008403361344537815,
#   'SystemSettings.exe': 0.025210084033613446,
#   'Spotify.exe': 0.008403361344537815,
#   'SndVol.exe': 0.008403361344537815},
#  'Installer.exe': {'chrome.exe': 1.0},
#  'LenovoVantage.exe': {'chrome.exe': 1.0},
#  'SearchApp.exe': {'explorer.exe': 0.13333333333333333,
#   'StartMenuExperienceHost.exe': 0.13333333333333333,
#   'chrome.exe': 0.35555555555555557,
#   'DB Browser for SQLite.exe': 0.08888888888888889,
#   'cmd.exe': 0.044444444444444446,
#   'notepad++.exe': 0.044444444444444446,
#   'npp.8.1.9.2.Installer.exe': 0.022222222222222223,
#   'Discord.exe': 0.044444444444444446,
#   'mmc.exe': 0.022222222222222223,
#   'ShellExperienceHost.exe': 0.022222222222222223,
#   'WinStore.App.exe': 0.022222222222222223,
#   'Netflix.exe': 0.044444444444444446,
#   'SystemSettings.exe': 0.022222222222222223},
#  'StartMenuExperienceHost.exe': {'cmd.exe': 0.18181818181818182,
#   'Netflix.exe': 0.18181818181818182,
#   'chrome.exe': 0.18181818181818182,
#   'SearchApp.exe': 0.36363636363636365,
#   'SystemSettings.exe': 0.09090909090909091},
#  'DB Browser for SQLite.exe': {'explorer.exe': 0.3719512195121951,
#   'SearchApp.exe': 0.012195121951219513,
#   'chrome.exe': 0.14634146341463414,
#   'Spotify.exe': 0.024390243902439025,
#   'devenv.exe': 0.27439024390243905,
#   'msedge.exe': 0.024390243902439025,
#   'Discord.exe': 0.03048780487804878,
#   'cmd.exe': 0.012195121951219513,
#   'Teams.exe': 0.06707317073170732,
#   'Taskmgr.exe': 0.006097560975609756,
#   'ScreenClippingHost.exe': 0.024390243902439025,
#   'Netflix.exe': 0.006097560975609756},
#  'python.exe': {'explorer.exe': 0.11764705882352941,
#   'cmd.exe': 0.17647058823529413,
#   'Netflix.exe': 0.29411764705882354,
#   'Discord.exe': 0.17647058823529413,
#   'ScreenSketch.exe': 0.058823529411764705,
#   'ScreenClippingHost.exe': 0.11764705882352941,
#   'chrome.exe': 0.058823529411764705},
#  'Taskmgr.exe': {'chrome.exe': 0.2,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.06666666666666667,
#   'GitHubDesktop.exe': 0.06666666666666667,
#   'explorer.exe': 0.13333333333333333,
#   'devenv.exe': 0.13333333333333333,
#   'cmd.exe': 0.06666666666666667,
#   'Spotify.exe': 0.06666666666666667,
#   'Teams.exe': 0.06666666666666667,
#   'DB Browser for SQLite.exe': 0.06666666666666667,
#   'msedge.exe': 0.06666666666666667,
#   'vpnui.exe': 0.06666666666666667},
#  'notepad++.exe': {'explorer.exe': 0.42857142857142855,
#   'GUP.exe': 0.07142857142857142,
#   'mmc.exe': 0.21428571428571427,
#   'cmd.exe': 0.07142857142857142,
#   'chrome.exe': 0.21428571428571427},
#  'GUP.exe': {'SearchApp.exe': 1.0},
#  'npp.8.1.9.2.Installer.exe': {'SearchApp.exe': 1.0},
#  'mmc.exe': {'explorer.exe': 0.3,
#   'notepad++.exe': 0.1,
#   'chrome.exe': 0.3,
#   'DB Browser for SQLite.exe': 0.1,
#   'Discord.exe': 0.1,
#   'SearchApp.exe': 0.1},
#  'notepad.exe': {'explorer.exe': 0.13333333333333333,
#   'chrome.exe': 0.5333333333333333,
#   'Spotify.exe': 0.06666666666666667,
#   'Discord.exe': 0.06666666666666667,
#   'Teams.exe': 0.06666666666666667,
#   'GitHubDesktop.exe': 0.06666666666666667,
#   'devenv.exe': 0.06666666666666667},
#  'HxOutlook.exe': {'chrome.exe': 0.5, 'explorer.exe': 0.5},
#  'SndVol.exe': {'Spotify.exe': 0.03125,
#   'Discord.exe': 0.15625,
#   'chrome.exe': 0.375,
#   'explorer.exe': 0.25,
#   'ShellExperienceHost.exe': 0.03125,
#   'Zoom.exe': 0.03125,
#   'SystemSettings.exe': 0.03125,
#   'StartMenuExperienceHost.exe': 0.03125,
#   'Teams.exe': 0.03125,
#   'steamwebhelper.exe': 0.03125},
#  'Microsoft.Notes.exe': {'notepad.exe': 0.3333333333333333,
#   'chrome.exe': 0.6666666666666666},
#  'ScreenClippingHost.exe': {'chrome.exe': 0.3333333333333333,
#   'Discord.exe': 0.047619047619047616,
#   'Teams.exe': 0.047619047619047616,
#   'DB Browser for SQLite.exe': 0.09523809523809523,
#   'explorer.exe': 0.09523809523809523,
#   'PickerHost.exe': 0.09523809523809523,
#   'cmd.exe': 0.047619047619047616,
#   'ScreenSketch.exe': 0.14285714285714285,
#   'python.exe': 0.047619047619047616,
#   'Zoom.exe': 0.047619047619047616},
#  'GitHubDesktop.exe': {'explorer.exe': 0.625,
#   'ShellExperienceHost.exe': 0.125,
#   'chrome.exe': 0.125,
#   'Taskmgr.exe': 0.125},
#  'WerFault.exe': {'explorer.exe': 1.0},
#  'devenv.exe': {'cmd.exe': 0.0125,
#   'ShellExperienceHost.exe': 0.00625,
#   'chrome.exe': 0.234375,
#   'explorer.exe': 0.26875,
#   'VsDebugConsole.exe': 0.15,
#   'DB Browser for SQLite.exe': 0.071875,
#   'Spotify.exe': 0.015625,
#   'Teams.exe': 0.178125,
#   'msedge.exe': 0.0125,
#   'Discord.exe': 0.040625,
#   'Taskmgr.exe': 0.003125,
#   'Microsoft.AAD.BrokerPlugin.exe': 0.003125,
#   'SndVol.exe': 0.003125},
#  'VsDebugConsole.exe': {'devenv.exe': 0.7,
#   'chrome.exe': 0.06,
#   'explorer.exe': 0.2,
#   'DB Browser for SQLite.exe': 0.02,
#   'Teams.exe': 0.02},
#  'OpenWith.exe': {'explorer.exe': 1.0},
#  'LockApp.exe': {'Teams.exe': 0.2,
#   'explorer.exe': 0.4,
#   'SystemSettings.exe': 0.2,
#   'ApplicationFrameHost.exe': 0.2},
#  'WindowsCamera.exe': {'chrome.exe': 0.5714285714285714,
#   'explorer.exe': 0.42857142857142855},
#  'Video.UI.exe': {'explorer.exe': 0.6666666666666666,
#   'chrome.exe': 0.3333333333333333},
#  'EaseOfAccessDialog.exe': {'chrome.exe': 1.0},
#  'ApplicationFrameHost.exe': {'Discord.exe': 0.5, 'chrome.exe': 0.5},
#  'WinStore.App.exe': {'chrome.exe': 0.4,
#   'cmd.exe': 0.2,
#   'Netflix.exe': 0.2,
#   'rundll32.exe': 0.2},
#  'rundll32.exe': {'explorer.exe': 0.6, 'WinStore.App.exe': 0.4},
#  'Netflix.exe': {'WinStore.App.exe': 0.01639344262295082,
#   'explorer.exe': 0.22950819672131148,
#   'chrome.exe': 0.39344262295081966,
#   'ShellExperienceHost.exe': 0.08196721311475409,
#   'NVIDIA Notification.exe': 0.01639344262295082,
#   'SystemSettings.exe': 0.03278688524590164,
#   'Spotify.exe': 0.09836065573770492,
#   'StartMenuExperienceHost.exe': 0.03278688524590164,
#   'python.exe': 0.04918032786885246,
#   'Discord.exe': 0.03278688524590164,
#   'Teams.exe': 0.01639344262295082},
#  'NVIDIA Notification.exe': {'Netflix.exe': 1.0},
#  'PaintStudio.View.exe': {'explorer.exe': 1.0},
#  'PickerHost.exe': {'chrome.exe': 0.5, 'ScreenSketch.exe': 0.5},
#  'ScreenSketch.exe': {'cmd.exe': 0.4, 'explorer.exe': 0.2, 'python.exe': 0.4},
#  'Microsoft.Photos.exe': {'explorer.exe': 0.4, 'chrome.exe': 0.6},
#  'zCefAgent.exe': {'chrome.exe': 1.0},
#  'steam.exe': {'explorer.exe': 0.09090909090909091,
#   'SndVol.exe': 0.09090909090909091,
#   'chrome.exe': 0.2727272727272727,
#   'Discord.exe': 0.09090909090909091,
#   'steamwebhelper.exe': 0.45454545454545453},
#  'steamwebhelper.exe': {'steam.exe': 0.3333333333333333,
#   'ShellExperienceHost.exe': 0.08333333333333333,
#   'chrome.exe': 0.25,
#   'explorer.exe': 0.08333333333333333,
#   'SndVol.exe': 0.16666666666666666,
#   'Teams.exe': 0.08333333333333333},
#  'msiexec.exe': {'chrome.exe': 1.0},
#  'vpnui.exe': {'cmd.exe': 0.14285714285714285,
#   'explorer.exe': 0.42857142857142855,
#   'Taskmgr.exe': 0.14285714285714285,
#   'chrome.exe': 0.14285714285714285,
#   'Netflix.exe': 0.14285714285714285},
#  'Anaconda3-2021.11-Windows-x86_64.exe': {'chrome.exe': 0.5, 'cmd.exe': 0.5}}
